# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras import regularizers
from keras.layers import Dense, LSTM, Activation, Input, add
from keras.models import Sequential, Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import xlrd
import datetime
import os
import tensorflow as tf
from keras.utils import plot_model
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def parser(x):
    return pd.datetime.strptime('190'+x,'%Y-%m')

def train_test_split(df,rate = 0.5):
    train,test = df[:int(df.shape[0]*rate)+1],df[int(df.shape[0]*rate)+1:]
    return (train,test)

def timeseries_to_supervised(data,lag = 1):
    df = pd.DataFrame(data)
   #print(df.shape)
    columns = [df.shift(i) for i in range(1,lag+1)]
    #print(columns)
    columns.append(df)
    df = pd.concat(columns,axis = 1)
    df.fillna(0,inplace = True)
    #print(df.shape)
    return df

def difference(df,interval = 1):
    diff = list()
    for i in range(interval,df.shape[0]):
        diff.append(df[i] - df[i-interval])
    return pd.Series(diff)

def inverse_difference(history,yhat,interval = 1):
    return yhat + history[-interval]

def train_test_scale(train,test):
    scaler = MinMaxScaler(feature_range = (-1,1))
    scaler = scaler.fit(train)
    train = train.reshape(train.shape[0],train.shape[1])
    test = test.reshape(test.shape[0],test.shape[1])
    scaled_train = scaler.transform(train)
    scaled_test = scaler.transform(test)
    
    return scaled_train,scaled_test,scaler

def invert_scale(scaler,X,value):
    new_row = [x for x in X] + [value]
    array = np.array(new_row)
    array = array.reshape(1,len(array))
    inverted = scaler.inverse_transform(array)
    return inverted[0,-1]
    
def fit_lstm_1(train,batch_size,epochs,neurons):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0],X.shape[1],1)
    inputs = Input(batch_shape = (batch_size,X.shape[1],X.shape[2]))
    lstm_layer_1 = LSTM(neurons,batch_input_shape = (batch_size,X.shape[1],X.shape[2]),
                        activation = 'relu',kernel_regularizer = regularizers.l2(0.1),
                        recurrent_regularizer = regularizers.l2(0.03),
                        bias_regularizer = regularizers.l2(0.01),
                        stateful = True,return_sequences = False)(inputs)
    dense_1 = Dense(neurons,activation = 'relu',name = 'dense_1')(lstm_layer_1)
    added_0 = add([lstm_layer_1,dense_1])
    dense_2 = Dense(neurons,activation = 'relu',name = 'dense_2')(dense_1)
    added_1 = add([dense_2,added_0])
    dense_3 = Dense(neurons,activation = 'relu',name = 'dense_3')(added_1)
    added_2 = add([dense_3,added_1])
    dense_4 = Dense(neurons,activation = 'relu',name = 'dense_4')(added_2)
    added_3 = add([dense_4,added_2])
    dense_5 = Dense(neurons,activation = 'relu',name = 'dense_5')(added_3)
    added_4 = add([dense_5,added_3])
    dense_6 = Dense(neurons,activation = 'relu',name = 'dense_6')(added_4)
    added_5 = add([dense_6,added_4])
    dense_7 = Dense(neurons,activation = 'relu',name = 'dense_7')(added_5)
    added_6 = add([dense_7,added_5])
    dense_8 = Dense(neurons,activation = 'relu',name = 'dense_8')(added_6)
    added_7 = add([dense_8,added_6])
    dense_9 = Dense(neurons,activation = 'tanh',name = 'dense_9')(added_7)
    added_8 = add([dense_9,added_7])
    dense_10 = Dense(neurons,activation = 'tanh',name = 'dense_10')(added_8)
    added_9 = add([dense_10,added_8])
    output = Dense(1,name = 'output')(added_9)
    model = Model(inputs = inputs,outputs = output)
    model.compile(optimizer = 'adam',loss = 'mean_squared_error')
    
    try:
        model.load_weights('model_1_weight.h5')
    except:
        pass
    
    historys = list()
    for i in range(epochs):
        history = model.fit(X,y,epochs = 1,batch_size = batch_size,verbose = 0,shuffle = False)
        model.reset_states()
        historys.append(history.history['loss'])
        print('Epoch:'+str(i+1)+' Loss:'+str(history.history['loss']))
        
    model.save_weights('model_1_weight.h5')
    
    return model,historys

def fit_lstm_2(train,batch_size,epochs,neurons):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    inputs = Input(batch_shape = (batch_size,X.shape[1],X.shape[2]))
    lstm_layer_1 = LSTM(neurons,batch_input_shape = (batch_size,X.shape[1],X.shape[2]),
                        activation = 'relu',kernel_regularizer = regularizers.l2(0.03),
                        recurrent_regularizer = regularizers.l2(0.03),
                        bias_regularizer = regularizers.l2(0.01),
                        stateful = True,return_sequences = False)(inputs)
    dense_1 = Dense(neurons,activation = 'relu',name = 'dense_1')(lstm_layer_1)
    added_0 = add([lstm_layer_1,dense_1])
    dense_2 = Dense(neurons,activation = 'relu',name = 'dense_2')(added_0)
    dense_3 = Dense(neurons,activation = 'relu',name = 'dense_3')(dense_2)
    added_1 = add([dense_2,dense_3,added_0])
    dense_4 = Dense(neurons,activation = 'relu',name = 'dense_4')(added_1)
    dense_5 = Dense(neurons,activation = 'relu',name = 'dense_5')(dense_4)
    added_2 = add([dense_4,dense_5,added_1])
    dense_6 = Dense(neurons,activation = 'relu',name = 'dense_6')(added_2)
    dense_7 = Dense(neurons,activation = 'relu',name = 'dense_7')(dense_6)
    added_3 = add([dense_6,dense_7,added_2])
    dense_8 = Dense(neurons,activation = 'relu',name = 'dense_8')(added_3)
    dense_9 = Dense(neurons,activation = 'relu',name = 'dense_9')(dense_8)
    added_4 = add([dense_8,dense_9,added_3])
    output = Dense(1,name = 'output')(added_4)
    model = Model(inputs = inputs,outputs = output)
    model.compile(optimizer = 'adam',loss = 'mean_squared_error')
     
    try:
        model.load_weights('model_2_weight.h5')
    except:
        pass
    
    historys = list()
    for i in range(epochs):
        history = model.fit(X,y,epochs = 1,batch_size = batch_size,verbose = 0,shuffle = False)
        model.reset_states()
        historys.append(history.history['loss'])
        print('Epoch:'+str(i+1)+' Loss:'+str(history.history['loss']))
        
    model.save_weights('model_2_weight.h5')
    
    return model,historys

def fit_lstm_3(train,batch_size,epochs,neurons):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    #model = Sequential()
    inputs = Input(batch_shape = (batch_size,X.shape[1],X.shape[2]),name = 'input')
    lstm_layer_1 = LSTM(neurons,batch_input_shape = (batch_size,X.shape[1],X.shape[2]),
                        activation = 'relu',kernel_regularizer = regularizers.l2(0.01),
                        recurrent_regularizer = regularizers.l2(0.01),
                        bias_regularizer = regularizers.l2(0.01),
                        stateful = True,return_sequences = True,
                       name = 'lstm_1')(inputs)
    lstm_layer_2 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = True,name = 'lstm_2')(lstm_layer_1)
    lstm_layer_3 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = True,name = 'lstm_3')(lstm_layer_2)
    lstm_layer_4 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = True,name = 'lstm_4')(lstm_layer_3)
    lstm_layer_5 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = True,name = 'lstm_5')(lstm_layer_4)
    lstm_layer_6 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = True,name = 'lstm_6')(lstm_layer_5)
    lstm_layer_7 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = True,name = 'lstm_7')(lstm_layer_6)
    lstm_layer_8 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = True,name = 'lstm_8')(lstm_layer_7)
    lstm_layer_9 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = True,name = 'lstm_9')(lstm_layer_8)
    lstm_layer_10 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = True,name = 'lstm_10')(lstm_layer_9)
    lstm_layer_11 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = True,name = 'lstm_11')(lstm_layer_10)
    lstm_layer_12 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = True,name = 'lstm_12')(lstm_layer_11)
    lstm_layer_13 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = True,name = 'lstm_13')(lstm_layer_12)
    lstm_layer_14 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = True,name = 'lstm_14')(lstm_layer_13)
    lstm_layer_15 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = True,name = 'lstm_15')(lstm_layer_14)
    lstm_layer_16 = LSTM(neurons,activation = 'relu',stateful = True,return_sequences = False,name = 'lstm_16')(lstm_layer_15)
    output = Dense(1,name = 'output')(lstm_layer_16)
    model = Model(inputs = inputs,outputs = output)
    model.compile(optimizer = 'adam',loss = 'mean_squared_error')
    
    try:
        model.load_weights('model_2_weight.h5')
    except:
        pass
    
    historys = list()
    for i in range(epochs):
        history = model.fit(X,y,epochs = 1,batch_size = batch_size,verbose = 0,shuffle = False)
        model.reset_states()
        historys.append(history.history['loss'])
        print('Epoch:'+str(i+1)+' Loss:'+str(history.history['loss']))
        
    model.save_weights('model_2_weight.h5')
    
    return model,historys

def fit_lstm_4(train,batch_size,epochs,neurons):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    #model = Sequential()
    inputs = Input(batch_shape = (batch_size,X.shape[1],X.shape[2]),name = 'input')
    lstm_layer_1 = LSTM(neurons,batch_input_shape = (batch_size,X.shape[1],X.shape[2]),
                        activation = 'relu',kernel_regularizer = regularizers.l2(0.01),
                        recurrent_regularizer = regularizers.l2(0.01),
                        bias_regularizer = regularizers.l2(0.01),
                        stateful = True,return_sequences = False,
                       name = 'lstm_1')(inputs)
    output = Dense(1,name = 'output')(lstm_layer_1)
    model = Model(inputs = inputs,outputs = output)
    model.compile(optimizer = 'adam',loss = 'mean_squared_error')
    
    try:
        model.load_weights('model_2_weight.h5')
    except:
        pass
    
    historys = list()
    for i in range(epochs):
        history = model.fit(X,y,epochs = 1,batch_size = batch_size,verbose = 0,shuffle = False)
        model.reset_states()
        historys.append(history.history['loss'])
        print('Epoch:'+str(i+1)+' Loss:'+str(history.history['loss']))
        
    model.save_weights('model_2_weight.h5')
    
    return model,historys

def forecast_lstm(model,batch_size,X):
    X = X.reshape(1,1,len(X))
    yhat = model.predict(X,batch_size = batch_size)
    return yhat[0,0]

def plot_loss(historys):
    plt.plot(range(1,len(historys)+1),historys)
    plt.title('Learning Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.show()

def mean_absolute_percentage_error(y_true,y_pred):
    return np.sum(np.divide(np.absolute(np.subtract(y_true,y_pred)),y_true))/len(y_true)

def mean_absolute_error(y_true,y_pred):
    return np.sum(np.absolute(np.subtract(y_true,y_pred)))/len(y_true)

def get_session(gpu_fraction=0.3):

    num_threads = os.environ.get('OMP_NUM_THREADS')
    gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=gpu_fraction)

    if num_threads:
        return tf.Session(config=tf.ConfigProto(
            gpu_options=gpu_options, intra_op_parallelism_threads=num_threads))
    else:
        return tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

# %%
#KTF.set_session(get_session())

# time start
starttime = datetime.datetime.now()

# load dataset
print('====Loading dataset====')
data = xlrd.open_workbook('Data.xls')
MAPE = []
for i in range(11,12):
    table = data.sheets()[i]
    raw_flow = table.col_values(0)
    flow = np.array([i for i in raw_flow[1:]])
    series = pd.DataFrame(flow)

    #initialze parameters
    print('====Setting parameters====')
    neurons = 32
    batch_size = 1
    time_step = 1
    epochs = 20
    time_intervals = [144]
    for j in range(len(time_intervals)):
        print('====Transforming data====')
        # transform data to be stationary
        raw_values = series.values
        diff_values = difference(raw_values,time_intervals[j]) # 144 here represents the time interval

        # transform data to be supervised learning
        supervised = timeseries_to_supervised(diff_values,1) # the 1 here is refered to time_step
        supervised_values = supervised.values

        # split data into train and test-sets
        print('====Spliting data====')
        (train,test) = train_test_split(supervised_values,rate = 0.92)

        # transform the scale of the data
        scaled_train,scaled_test,scaler = train_test_scale(train,test)

        # fit the modelto 
        print('====Training data====')
        lstm_model_1,historys_1 = fit_lstm_1(scaled_train,batch_size = batch_size,
                                             epochs = 10,neurons = neurons)
        print('Model 1 trained')
        # lstm_model_2,historys_2 = fit_lstm_2(scaled_train,batch_size = batch_size,
       # epochs = 10,neurons = neurons)
        # print('Model 2 trained')

        # forecast the entire training dataset to build up state for forecasting
        print('====Predicting====')
        reshaped_train = scaled_train[:,0].reshape(len(scaled_train),1,1)
        lstm_model_1.predict(reshaped_train,batch_size = 1)
        # lstm_model_2.predict(reshaped_train,batch_size = 1)



        #plot_model(lstm_model_1,to_file = 'lstm_model_1.png')
        #plot_model(lstm_model_2,to_file = 'lstm_model_2.png')


        # walk-forward validation on the test data
        predictions_1 = list()
        # predictions_2 = list() 
        expectation = list()
        for i in range(len(scaled_test)):

            # make one-step forecast
            X, y = scaled_test[i, 0:-1], scaled_test[i, -1]
            yhat_1 = forecast_lstm(lstm_model_1, 1, X)
        #     yhat_2 = forecast_lstm(lstm_model_2, 1, X)


            # invert scaling
            yhat_1 = invert_scale(scaler, X, yhat_1)
        #     yhat_2 = invert_scale(scaler, X, yhat_2)


            # invert differencing
            yhat_1 = inverse_difference(raw_values, yhat_1, len(scaled_test)+time_intervals[j]-i)
        #     yhat_2 = inverse_difference(raw_values, yhat_2, len(scaled_test)+144-i)

            # store forecast
            predictions_1.append(yhat_1)
        #     predictions_2.append(yhat_2)

            #print(predictions_2)
            # here the predicted time point has a time gap of time_interval with 
            # the time point we use to inverse the difference, 
            # so it's the reciprocal len(scaled_test)+i time point.
            expected = raw_values[-len(scaled_test)+i]
            expectation.append(expected)
            #scaled_train = np.vstack(scaled_train,np.array(scaled_test[i,:]))
            #lstm_model_1,historys_1 = fit_lstm_1(scaled_train,batch_size = batch_size,
                                               #  epochs = epochs,neurons = neurons)
            #if i == len(scaled_test)-1:
            #print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat_22, expected))

        # time end
        endtime = datetime.datetime.now()
        print('Total excuting time: '+str((endtime - starttime).seconds)+'s')

        # report performance
        rmse_1 = sqrt(mean_squared_error(expectation[:int(len(predictions_1))],
                                         predictions_1[:int(len(predictions_1))]))
        # rmse_2 = sqrt(mean_squared_error(expectation[:int(len(predictions_2))], 
        # predictions_2[:int(len(predictions_2))]))

        mape_1 = mean_absolute_percentage_error(expectation,predictions_1)
        # mape_2 = mean_absolute_percentage_error(expectation,predictions_2)
        MAPE.append(mape_1)
        mae_1 = mean_absolute_error(expectation,predictions_1)
        # mae_2 = mean_absolute_error(expectation,predictions_2)

        print(rmse_1)
        # print(rmse_2)

        print(str(mape_1 * 100)+'\%')
        # print(str(mape_2 * 100)+'%')

        print(mae_1)
        # print(mae_2)
    for i in range(len(MAPE)):
        print(str(MAPE[i]*100))
    print('one detector is done')
# Out:
# ====Loading dataset====
# ====Setting parameters====
# ====Transforming data====
# ====Spliting data====
# ====Training data====
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# Epoch:1 Loss:[0.044855248335492925]
# Epoch:2 Loss:[0.04486605220378274]
# Epoch:3 Loss:[0.04472170249364609]
# Epoch:4 Loss:[0.044723838910507574]
# Epoch:5 Loss:[0.044739229838255554]
# Epoch:6 Loss:[0.044656028495705775]
# Epoch:7 Loss:[0.0447970485683641]
# Epoch:8 Loss:[0.04468072962314387]
# Epoch:9 Loss:[0.044726149911387646]
# Epoch:10 Loss:[0.044684826773401416]
# Model 1 trained
# ====Predicting====
# Total excuting time: 206s
# 140.3460872031659
# 52.17929772286774\%
# 75.09719370708797
# 52.17929772286774
# one detector is done

# %%
# walk-forward validation on the test data
predictions_1 = list()
# predictions_2 = list() 
expectation = list()
for i in range(len(scaled_test)):
    # make one-step forecast
    X, y = scaled_test[i, 0:-1], scaled_test[i, -1]
    yhat_1 = forecast_lstm(lstm_model_1, 1, X)
#     yhat_2 = forecast_lstm(lstm_model_2, 1, X)

    # invert scaling
    yhat_1 = invert_scale(scaler, X, yhat_1)1
#     yhat_2 = invert_scale(scaler, X, yhat_2)

    
    # invert differencing
     yhat_1 = inverse_difference(raw_values, yhat_1, len(scaled_test)+time_interval-i)
#     yhat_2 = inverse_difference(raw_values, yhat_2, len(scaled_test)+144-i)

    # store forecast
    predictions_1.append(yhat_1)
#     predictions_2.append(yhat_2)

    #print(predictions_2)
    expected = raw_values[len(train) + i + 1]
    expectation.append(expected)
    #scaled_train = np.vstack(scaled_train,np.array(scaled_test[i,:]))
    #lstm_model_1,historys_1 = fit_lstm_1(scaled_train,batch_size = batch_size,
                                       #  epochs = epochs,neurons = neurons)
    #if i == len(scaled_test)-1:
    #print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat_22, expected))

# time end
endtime = datetime.datetime.now()
print('Total excuting time: '+str((endtime - starttime).seconds)+'s')
# Out:
# Total excuting time: 361s

# %%
# # report performance
# rmse_1 = sqrt(mean_squared_error(expectation[:int(len(predictions_1))], predictions_1[:int(len(predictions_1))]))
# # rmse_2 = sqrt(mean_squared_error(expectation[:int(len(predictions_2))], predictions_2[:int(len(predictions_2))]))

# mape_1 = mean_absolute_percentage_error(expectation,predictions_1)
# # mape_2 = mean_absolute_percentage_error(expectation,predictions_2)

# mae_1 = mean_absolute_error(expectation,predictions_1)
# # mae_2 = mean_absolute_error(expectation,predictions_2)

# print(rmse_1)
# # print(rmse_2)

# print(str(mape_1 * 100)+'%')
# # print(str(mape_2 * 100)+'%')

# print(mae_1)
# # print(mae_2)

# # line plot of observed vs predicted
figsize = (30,20)
figure,ax = plt.subplots(figsize = figsize)

font1 = {'family' : 'Times New Roman',  
'weight' : 'normal',  
'size'   : 40,  
}  

plt.tick_params(labelsize=40)  
labels = ax.get_xticklabels() + ax.get_yticklabels()  
[label.set_fontname('Times New Roman') for label in labels]  

font2 = {'family' : 'Times New Roman',  
'weight' : 'normal',  
'size'   : 50,  
}  

# plt.xlabel('Time Point',font2)
# plt.ylabel('Traffic Flow',font2)
# raw, = plt.plot(expectation[:int(len(predictions_1))],'ro',label = 'raw data')
# pre, = plt.plot(predictions_1[:int(len(predictions_1))],'b',label = 'predictions')
# legend = plt.legend(handles = [raw,pre],prop = font1)
# plt.savefig('pre.png')
# plt.show()


n_groups = len(MAPE);     

 
index = np.arange(n_groups)  
bar_width = 0.5

opacity = 0.4  
rects1 = plt.bar(index, MAPE, bar_width,alpha=opacity, color='b')   

plt.xlabel('detectors',font2)  
plt.ylabel('MAPE',font2)  
# plt.title('MAP')  
plt.xticks(index + bar_width, ('2010', '2011', '2013', '2023','2030', '2033','2052',
                               '3034','3035','4004','4005','4050','4051','5062'))  
plt.tick_params(labelsize=40) 
plt.ylim(0,0.6);  
plt.legend();  

plt.savefig('MAPEforSeveralDetectors.pdf')
plt.show();
# Out:
# No handles with labels found to put in legend.

# %%
mape = [6.50,9.70883,11.73778,17.88,15.914,18.45,19.969,33.693790,25.35856,27.5255,30.3058,32.67]
oneDay = [10.88]*12
oneWeek = [7.28]*12

figsize = (8,8)
figure,ax = plt.subplots(figsize = figsize)

font1 = {'family' : 'Times New Roman',  
'weight' : 'normal',  
'size'   : 10,  
}  

plt.tick_params(labelsize=40)  
labels = ax.get_xticklabels() + ax.get_yticklabels()  
[label.set_fontname('Times New Roman') for label in labels]  

font2 = {'family' : 'Times New Roman',  
'weight' : 'normal',  
'size'   : 20,  
}  


raw, = plt.plot(mape,'co-')
pre, = plt.plot(oneDay,'b',label = 'time_interval = 1 day')
pre2, = plt.plot(oneWeek,'g',label = 'time_interval = 1 week')
plt.tick_params(labelsize = 15) 
plt.xlabel('Time Interval',font2)  
plt.ylabel('MAPE (%)',font2)
plt.text(5,10.2,'MAPE = 10.88%',font1)
plt.text(5,6.5,'MAPE = 7.28%',font1)

plt.legend()
plt.plot(mape)
plt.savefig('Bound.pdf')

# %%
params = {
    'learning_rate': 0.03,
    'n_estimators': 3000,
    ',': 0.8,
    'colsample_bytree': 0.6,
    'max_depth': 10,
    'min_child_weight': 1,
    'reg_alpha': 0.1,
    'gamma': 0.7
}

print('====Transforming data====')
# transform data to be stationary
raw_values = series.values
diff_values = difference(raw_values,1)

# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values,1)
supervised_values = supervised.values

# split data into train and test-sets
print('====Spliting data====')
(train,test) = train_test_split(supervised_values,rate = 0.92)

# transform the scale of the data
scaled_train,scaled_test,scaler = train_test_scale(train,test)

X_train, y_train = scaled_train[:, 0:-1], scaled_train[:, -1]
X_test, y_test = scaled_test[:, 0:-1], scaled_test[:, -1]
eval_set = [(X_test, y_test)]

regressor = xgb.XGBRegressor(learning_rate=params['learning_rate'], n_estimators=params['n_estimators'],
                             booster='gbtree', objective='reg:linear', n_jobs=-1, subsample=params['subsample'],
                             colsample_bytree=params['colsample_bytree'], random_state=0,
                             max_depth=params['max_depth'], gamma=params['gamma'],silent = 1,
                             min_child_weight=params['min_child_weight'], reg_alpha=params['reg_alpha'])


regressor.fit(X_train, y_train, verbose=True, early_stopping_rounds=3000, eval_set=eval_set)

predictions = list()
expectations = list()
for i in range(len(scaled_test)):
    X, y = scaled_test[i, 0:-1], scaled_test[i, -1]
    X = X.reshape(len(X),1)
    yhat = regressor.predict(X)
    yhat = invert_scale(scaler, X, yhat)
    yhat = inverse_difference(raw_values, yhat, len(scaled_test)+1-i)
    predictions.append(yhat)
    expected = raw_values[len(train) + i + 1]
    expectations.append(expected)
    #print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
rmse = sqrt(mean_squared_error(expectations[:int(len(predictions))], predictions[:int(len(predictions))]))
# Out:
# ====Transforming data====
# ====Spliting data====
# [0]	validation_0-rmse:0.324135
# Will train until validation_0-rmse hasn't improved in 3000 rounds.
# [1]	validation_0-rmse:0.31613
# [2]	validation_0-rmse:0.308395
# [3]	validation_0-rmse:0.300939
# [4]	validation_0-rmse:0.293765
# [5]	validation_0-rmse:0.286826
# [6]	validation_0-rmse:0.280145
# [7]	validation_0-rmse:0.273758
# [8]	validation_0-rmse:0.267592
# [9]	validation_0-rmse:0.261662
# [10]	validation_0-rmse:0.25598
# [11]	validation_0-rmse:0.250533
# [12]	validation_0-rmse:0.245314
# [13]	validation_0-rmse:0.24028
# [14]	validation_0-rmse:0.235423
# [15]	validation_0-rmse:0.230741
# [16]	validation_0-rmse:0.226318
# [17]	validation_0-rmse:0.222078
# [18]	validation_0-rmse:0.217954
# [19]	validation_0-rmse:0.214037
# [20]	validation_0-rmse:0.210306
# [21]	validation_0-rmse:0.206752
# [22]	validation_0-rmse:0.203306
# [23]	validation_0-rmse:0.199989
# [24]	validation_0-rmse:0.196855
# [25]	validation_0-rmse:0.193871
# [26]	validation_0-rmse:0.190994
# [27]	validation_0-rmse:0.188247
# [28]	validation_0-rmse:0.185638
# [29]	validation_0-rmse:0.18317
# [30]	validation_0-rmse:0.18082
# [31]	validation_0-rmse:0.178582
# [32]	validation_0-rmse:0.176434
# [33]	validation_0-rmse:0.174365
# [34]	validation_0-rmse:0.172428
# [35]	validation_0-rmse:0.170604
# [36]	validation_0-rmse:0.168878
# [37]	validation_0-rmse:0.167221
# [38]	validation_0-rmse:0.165638
# [39]	validation_0-rmse:0.16417
# [40]	validation_0-rmse:0.162774
# [41]	validation_0-rmse:0.161419
# [42]	validation_0-rmse:0.160087
# [43]	validation_0-rmse:0.158901
# [44]	validation_0-rmse:0.157791
# [45]	validation_0-rmse:0.156704
# C:\Users\Zeren Tan\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# [46]	validation_0-rmse:0.15566
# [47]	validation_0-rmse:0.154709
# [48]	validation_0-rmse:0.153816
# [49]	validation_0-rmse:0.152987
# [50]	validation_0-rmse:0.152174
# [51]	validation_0-rmse:0.151421
# [52]	validation_0-rmse:0.150694
# [53]	validation_0-rmse:0.150023
# [54]	validation_0-rmse:0.149373
# [55]	validation_0-rmse:0.148776
# [56]	validation_0-rmse:0.1482
# [57]	validation_0-rmse:0.147672
# [58]	validation_0-rmse:0.147171
# [59]	validation_0-rmse:0.146705
# [60]	validation_0-rmse:0.146281
# [61]	validation_0-rmse:0.145864
# [2949]	validation_0-rmse:0.139749
# [2950]	validation_0-rmse:0.139748
# [2951]	validation_0-rmse:0.139748
# [2952]	validation_0-rmse:0.139748
# [2953]	validation_0-rmse:0.139747
# [2954]	validation_0-rmse:0.139747
# [2955]	validation_0-rmse:0.139747
# [2956]	validation_0-rmse:0.139746
# [2957]	validation_0-rmse:0.139746
# [2958]	validation_0-rmse:0.139746
# [2959]	validation_0-rmse:0.139747
# [2960]	validation_0-rmse:0.139746
# [2961]	validation_0-rmse:0.139747
# [2962]	validation_0-rmse:0.139746
# [2963]	validation_0-rmse:0.139747
# [2964]	validation_0-rmse:0.139747
# [2965]	validation_0-rmse:0.139747
# [2966]	validation_0-rmse:0.139746
# [2967]	validation_0-rmse:0.139746
# [2968]	validation_0-rmse:0.139746
# [2969]	validation_0-rmse:0.139746
# [2970]	validation_0-rmse:0.139746
# [2971]	validation_0-rmse:0.139747
# [2972]	validation_0-rmse:0.139746
# [2973]	validation_0-rmse:0.139747
# [2974]	validation_0-rmse:0.139746
# [2975]	validation_0-rmse:0.139745
# [2976]	validation_0-rmse:0.139745
# [2977]	validation_0-rmse:0.139745
# [2978]	validation_0-rmse:0.139744
# [2979]	validation_0-rmse:0.139744
# [2980]	validation_0-rmse:0.139744
# [2981]	validation_0-rmse:0.139744
# [2982]	validation_0-rmse:0.139744
# [2983]	validation_0-rmse:0.139743
# [2984]	validation_0-rmse:0.139743
# [2985]	validation_0-rmse:0.139743
# [2986]	validation_0-rmse:0.139744
# [2987]	validation_0-rmse:0.139743
# [2988]	validation_0-rmse:0.139742
# [2989]	validation_0-rmse:0.139744
# [2990]	validation_0-rmse:0.139743
# [2991]	validation_0-rmse:0.139744
# [2992]	validation_0-rmse:0.139744
# [2993]	validation_0-rmse:0.139744
# [2994]	validation_0-rmse:0.139745
# [2995]	validation_0-rmse:0.139745
# [2996]	validation_0-rmse:0.139746
# [2997]	validation_0-rmse:0.139745
# [2998]	validation_0-rmse:0.139745
# [2999]	validation_0-rmse:0.139744

# %%
rmse
mape = mean_absolute_percentage_error(expectations,predictions)
mape*100
# Out:
# 6.4337438798263324

# %%
figsize = (50,20)
figure,ax = plt.subplots(figsize = figsize)

raw_1, = plt.plot(predictions_1[:int(len(predictions)/10)],'ro',label = 'raw data')
pre_1, = plt.plot(predictions[:int(len(predictions)/10)],'b',label = 'predictions')
legend = plt.legend(handles = [raw_1,pre_1],prop = font1)
plt.show()

# %%
figsize = (30,20)
figure,ax = plt.subplots(figsize = figsize)

font1 = {'family' : 'Times New Roman',  
'weight' : 'normal',  
'size'   : 40,  
}  

plt.tick_params(labelsize=40)  
labels = ax.get_xticklabels() + ax.get_yticklabels()  
[label.set_fontname('Times New Roman') for label in labels]  

font2 = {'family' : 'Times New Roman',  
'weight' : 'normal',  
'size'   : 50,  
}  


n_groups = 5
index = np.arange(n_groups)  
bar_width = 0.5

opacity = 0.4  
NUM = (4,6,2,1,1)
# (30,30,40,20,20,20,30,30,20,40,30,120,70,30)
rects1 = plt.bar(index, NUM, bar_width,alpha=opacity, color='b')   

plt.xlabel('Time Interval',font2)  
 
plt.xticks(index, ('20','30','40','70','120'))  
plt.tick_params(labelsize=40) 
plt.ylim(0,0.6);  
plt.legend();  

plt.savefig('MAPEforSeveralDetectors.pdf')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Out:
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]
# [3.40176494]

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
from scipy import  stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.api import qqplot
# Out:
# C:\Users\Zeren Tan\Anaconda3\envs\tensorflow\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
data = xlrd.open_workbook('Data.xls')
table = data.sheets()[0]
table2 = data.sheets()[1]
raw_flow = table.col_values(0)
raw_flow2 = table2.col_values(0)
flow = np.array([i for i in raw_flow[1:]])
flow2 = np.array([i for i in raw_flow2[1:]])
series = pd.DataFrame(flow)

# %%
dta=pd.Series(flow[:int(len(flow)/50)])
dta.index = pd.Index(sm.tsa.datetools.dates_from_range('1001m1',length = int(len(flow)/50)))
dta.plot(figsize=(12,8))

# %%
fig = plt.figure(figsize=(12,8))
ax1= fig.add_subplot(111)
diff1 = dta.diff(1)
diff1.plot(ax=ax1)

# %%
fig = plt.figure(figsize=(12,8))
ax2= fig.add_subplot(111)
diff2 = dta.diff(2)
diff2.plot(ax=ax2)

# %%
dta= dta.diff(1)#我们已经知道要使用一阶差分的时间序列，之前判断差分的程序可以注释掉
fig = plt.figure(figsize=(12,8))
ax1=fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(dta,lags=1,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(dta,lags=1,ax=ax2)

# %%
arma_mod20 = sm.tsa.ARMA(dta,(7,0)).fit()
print(arma_mod20.aic,arma_mod20.bic,arma_mod20.hqic)
arma_mod30 = sm.tsa.ARMA(dta,(0,1)).fit()
print(arma_mod30.aic,arma_mod30.bic,arma_mod30.hqic)
arma_mod40 = sm.tsa.ARMA(dta,(7,1)).fit()
print(arma_mod40.aic,arma_mod40.bic,arma_mod40.hqic)
arma_mod50 = sm.tsa.ARMA(dta,(8,0)).fit()
print(arma_mod50.aic,arma_mod50.bic,arma_mod50.hqic)
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     302             try:
# --> 303                 values, tz = tslib.datetime_to_datetime64(arg)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib._check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1001-01-31 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow\lib\site-packages\statsmodels\tsa\base\tsa_model.py in _init_dates(self, dates, freq)
#      61                 try:
# ---> 62                     freq = datetools._infer_freq(dates)
#      63                 except:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\statsmodels\tsa\base\datetools.py in _infer_freq(dates)
#     294     from pandas.tseries.api import infer_freq
# --> 295     freq = infer_freq(dates)
#     296     return freq
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\tseries\frequencies.py in infer_freq(index, warn)
#     601         try:
# --> 602             index = pd.DatetimeIndex(index)
#     603         except AmbiguousTimeError:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\datetimes.py in __new__(cls, data, freq, start, end, periods, copy, name, tz, verify_integrity, normalize, closed, ambiguous, dtype, **kwargs)
#     341             data = tools.to_datetime(data, dayfirst=dayfirst,
# --> 342                                      yearfirst=yearfirst)
#     343
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     379     elif is_list_like(arg):
# --> 380         result = _convert_listlike(arg, box, format)
#     381     else:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     305             except (ValueError, TypeError):
# --> 306                 raise e
#     307
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     293                     yearfirst=yearfirst,
# --> 294                     require_iso8601=require_iso8601
#     295                 )
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib._check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1001-01-31 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-8e557a8328d4> in <module>()
# ----> 1 arma_mod20 = sm.tsa.ARMA(dta,(7,0)).fit()
#       2 print(arma_mod20.aic,arma_mod20.bic,arma_mod20.hqic)
#       3 arma_mod30 = sm.tsa.ARMA(dta,(0,1)).fit()
#       4 print(arma_mod30.aic,arma_mod30.bic,arma_mod30.hqic)
#       5 arma_mod40 = sm.tsa.ARMA(dta,(7,1)).fit()
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#     450     def __init__(self, endog, order, exog=None, dates=None, freq=None,
#     451                  missing='none'):
# --> 452         super(ARMA, self).__init__(endog, exog, dates, freq, missing=missing)
#     453         exog = self.data.exog  # get it after it's gone through processing
#     454         _check_estimable(len(self.endog), sum(order))
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\statsmodels\tsa\base\tsa_model.py in __init__(self, endog, exog, dates, freq, missing)
#      42     def __init__(self, endog, exog=None, dates=None, freq=None, missing='none'):
#      43         super(TimeSeriesModel, self).__init__(endog, exog, missing=missing)
# ---> 44         self._init_dates(dates, freq)
#      45
#      46     def _init_dates(self, dates, freq):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\statsmodels\tsa\base\tsa_model.py in _init_dates(self, dates, freq)
#      62                     freq = datetools._infer_freq(dates)
#      63                 except:
# ---> 64                     raise ValueError("Frequency inference failed. Use `freq` "
#      65                                      "keyword.")
#      66
#
# ValueError: Frequency inference failed. Use `freq` keyword.

# %%
predictions_2
# Out:
# [array([345.59823506]),
#  array([278.59823506]),
#  array([275.59823506]),
#  array([252.59823506]),
#  array([282.59823506]),
#  array([264.59823506]),
#  array([239.59823506]),
#  array([242.59823506]),
#  array([253.59823506]),
#  array([262.59823506]),
#  array([268.59823506]),
#  array([317.59823506]),
#  array([314.59823506]),
#  array([336.59823506]),
#  array([420.59823506]),
#  array([441.59823506]),
#  array([548.59823506]),
#  array([623.59823506]),
#  array([615.59823506]),
#  array([658.59823506]),
#  array([738.59823506]),
#  array([795.59823506]),
#  array([888.59823506]),
#  array([930.59823506]),
#  array([1016.59823506]),
#  array([987.59823506]),
#  array([1055.59823506]),
#  array([1098.59823506]),
#  array([1223.59823506]),
#  array([1302.59823506]),
#  array([1261.59823506]),
#  array([1240.59823506]),
#  array([1289.59823506]),
#  array([1425.59823506]),
#  array([1391.59823506]),
#  array([1397.59823506]),
#  array([1403.59823506]),
#  array([1354.59823506]),
#  array([1173.59823506]),
#  array([1309.59823506]),
#  array([1265.59823506]),
#  array([1251.59823506]),
#  array([1252.59823506]),
#  array([1403.59823506]),
#  array([1412.59823506]),
#  array([1349.59823506]),
#  array([1305.59823506]),
#  array([1257.59823506]),
#  array([1249.59823506]),
#  array([1370.59823506]),
#  array([1339.59823506]),
#  array([1297.59823506]),
#  array([1362.59823506]),
#  array([1246.59823506]),
#  array([1262.59823506]),
#  array([1231.59823506]),
#  array([1294.59823506]),
#  array([1296.59823506]),
#  array([1336.59823506]),
#  array([1339.59823506]),
#  array([1311.59823506]),
#  array([1377.59823506]),
#  array([1328.59823506]),
#  array([1350.59823506]),
#  array([1260.59823506]),
#  array([1292.59823506]),
#  array([1368.59823506]),
#  array([1281.59823506]),
#  array([1293.59823506]),
#  array([1359.59823506]),
#  array([1239.59823506]),
#  array([1120.59823506]),
#  array([1088.59823506]),
#  array([1135.59823506]),
#  array([1172.59823506]),
#  array([1258.59823506]),
#  array([1192.59823506]),
#  array([1220.59823506]),
#  array([1293.59823506]),
#  array([1209.59823506]),
#  array([1314.59823506]),
#  array([1268.59823506]),
#  array([1167.59823506]),
#  array([1213.59823506]),
#  array([1210.59823506]),
#  array([1303.59823506]),
#  array([1273.59823506]),
#  array([1334.59823506]),
#  array([1135.59823506]),
#  array([1276.59823506]),
#  array([1239.59823506]),
#  array([1200.59823506]),
#  array([1263.59823506]),
#  array([1252.59823506]),
#  array([1256.59823506]),
#  array([1296.59823506]),
#  array([1220.59823506]),
#  array([1247.59823506]),
#  array([1174.59823506]),
#  array([1209.59823506]),
#  array([1213.59823506]),
#  array([1210.59823506]),
#  array([1268.59823506]),
#  array([1267.59823506]),
#  array([1283.59823506]),
#  array([1237.59823506]),
#  array([1352.59823506]),
#  array([1309.59823506]),
#  array([1271.59823506]),
#  array([1284.59823506]),
#  array([1267.59823506]),
#  array([1221.59823506]),
#  array([1231.59823506]),
#  array([1259.59823506]),
#  array([1234.59823506]),
#  array([1155.59823506]),
#  array([1282.59823506]),
#  array([1200.59823506]),
#  array([1116.59823506]),
#  array([1111.59823506]),
#  array([1026.59823506]),
#  array([998.59823506]),
#  array([951.59823506]),
#  array([833.59823506]),
#  array([822.59823506]),
#  array([797.59823506]),
#  array([716.59823506]),
#  array([655.59823506]),
#  array([670.59823506]),
#  array([607.59823506]),
#  array([639.59823506]),
#  array([499.59823506]),
#  array([494.59823506]),
#  array([443.59823506]),
#  array([424.59823506]),
#  array([416.59823506]),
#  array([414.59823506]),
#  array([382.59823506]),
#  array([381.59823506]),
#  array([349.59823506]),
#  array([342.59823506]),
#  array([326.59823506]),
#  array([278.59823506]),
#  array([264.59823506]),
#  array([300.59823506]),
#  array([279.59823506]),
#  array([253.59823506]),
#  array([231.59823506]),
#  array([239.59823506]),
#  array([230.59823506]),
#  array([209.59823506]),
#  array([202.59823506]),
#  array([213.59823506]),
#  array([223.59823506]),
#  array([290.59823506]),
#  array([269.59823506]),
#  array([323.59823506]),
#  array([307.59823506]),
#  array([376.59823506]),
#  array([352.59823506]),
#  array([471.59823506]),
#  array([474.59823506]),
#  array([580.59823506]),
#  array([596.59823506]),
#  array([633.59823506]),
#  array([683.59823506]),
#  array([754.59823506]),
#  array([802.59823506]),
#  array([755.59823506]),
#  array([831.59823506]),
#  array([886.59823506]),
#  array([952.59823506]),
#  array([1036.59823506]),
#  array([1057.59823506]),
#  array([1124.59823506]),
#  array([1208.59823506]),
#  array([1221.59823506]),
#  array([1264.59823506]),
#  array([1323.59823506]),
#  array([1304.59823506]),
#  array([1229.59823506]),
#  array([1395.59823506]),
#  array([1392.59823506]),
#  array([1407.59823506]),
#  array([1452.59823506]),
#  array([1409.59823506]),
#  array([1260.59823506]),
#  array([1268.59823506]),
#  array([1324.59823506]),
#  array([1356.59823506]),
#  array([1327.59823506]),
#  array([1375.59823506]),
#  array([1375.59823506]),
#  array([1375.59823506]),
#  array([1428.59823506]),
#  array([1337.59823506]),
#  array([1182.59823506]),
#  array([1178.59823506]),
#  array([1034.59823506]),
#  array([1284.59823506]),
#  array([1366.59823506]),
#  array([1324.59823506]),
#  array([1412.59823506]),
#  array([1357.59823506]),
#  array([1336.59823506]),
#  array([1444.59823506]),
#  array([1335.59823506]),
#  array([1417.59823506]),
#  array([1364.59823506]),
#  array([1376.59823506]),
#  array([1289.59823506]),
#  array([1359.59823506]),
#  array([1439.59823506]),
#  array([1327.59823506]),
#  array([1130.59823506]),
#  array([1208.59823506]),
#  array([1386.59823506]),
#  array([1352.59823506]),
#  array([1325.59823506]),
#  array([1301.59823506]),
#  array([1333.59823506]),
#  array([1307.59823506]),
#  array([1327.59823506]),
#  array([1376.59823506]),
#  array([1329.59823506]),
#  array([1414.59823506]),
#  array([1319.59823506]),
#  array([1337.59823506]),
#  array([1288.59823506]),
#  array([1305.59823506]),
#  array([1322.59823506]),
#  array([1361.59823506]),
#  array([1299.59823506]),
#  array([1294.59823506]),
#  array([1384.59823506]),
#  array([1311.59823506]),
#  array([1368.59823506]),
#  array([1304.59823506]),
#  array([1270.59823506]),
#  array([1310.59823506]),
#  array([1285.59823506]),
#  array([1199.59823506]),
#  array([1273.59823506]),
#  array([1249.59823506]),
#  array([1236.59823506]),
#  array([1212.59823506]),
#  array([1325.59823506]),
#  array([1259.59823506]),
#  array([1324.59823506]),
#  array([1344.59823506]),
#  array([1282.59823506]),
#  array([998.59823506]),
#  array([1201.59823506]),
#  array([1289.59823506]),
#  array([1309.59823506]),
#  array([1299.59823506]),
#  array([1276.59823506]),
#  array([1323.59823506]),
#  array([1286.59823506]),
#  array([1256.59823506]),
#  array([1244.59823506]),
#  array([1245.59823506]),
#  array([1120.59823506]),
#  array([1111.59823506]),
#  array([1009.59823506]),
#  array([955.59823506]),
#  array([924.59823506]),
#  array([785.59823506]),
#  array([738.59823506]),
#  array([707.59823506]),
#  array([671.59823506]),
#  array([618.59823506]),
#  array([579.59823506]),
#  array([562.59823506]),
#  array([520.59823506]),
#  array([439.59823506]),
#  array([413.59823506]),
#  array([345.59823506]),
#  array([321.59823506]),
#  array([316.59823506]),
#  array([297.59823506]),
#  array([317.59823506]),
#  array([339.59823506]),
#  array([323.59823506]),
#  array([271.59823506]),
#  array([260.59823506]),
#  array([232.59823506]),
#  array([224.59823506]),
#  array([227.59823506]),
#  array([231.59823506]),
#  array([215.59823506]),
#  array([175.59823506]),
#  array([183.59823506]),
#  array([155.59823506]),
#  array([171.59823506]),
#  array([175.59823506]),
#  array([202.59823506]),
#  array([183.59823506]),
#  array([225.59823506]),
#  array([234.59823506]),
#  array([271.59823506]),
#  array([305.59823506]),
#  array([377.59823506]),
#  array([456.59823506]),
#  array([517.59823506]),
#  array([634.59823506]),
#  array([729.59823506]),
#  array([943.59823506]),
#  array([1122.59823506]),
#  array([1319.59823506]),
#  array([1347.59823506]),
#  array([1424.59823506]),
#  array([1439.59823506]),
#  array([1479.59823506]),
#  array([1450.59823506]),
#  array([1549.59823506]),
#  array([1537.59823506]),
#  array([1559.59823506]),
#  array([1418.59823506]),
#  array([1315.59823506]),
#  array([1404.59823506]),
#  array([1442.59823506]),
#  array([1317.59823506]),
#  array([1341.59823506]),
#  array([1286.59823506]),
#  array([1390.59823506]),
#  array([1343.59823506]),
#  array([1346.59823506]),
#  array([1305.59823506]),
#  array([1302.59823506]),
#  array([1232.59823506]),
#  array([1365.59823506]),
#  array([1296.59823506]),
#  array([1138.59823506]),
#  array([1032.59823506]),
#  array([1130.59823506]),
#  array([1161.59823506]),
#  array([1111.59823506]),
#  array([1036.59823506]),
#  array([1148.59823506]),
#  array([1070.59823506]),
#  array([1171.59823506]),
#  array([1156.59823506]),
#  array([1165.59823506]),
#  array([1295.59823506]),
#  array([1294.59823506]),
#  array([1344.59823506]),
#  array([1329.59823506]),
#  array([1294.59823506]),
#  array([1332.59823506]),
#  array([1312.59823506]),
#  array([1312.59823506]),
#  array([1263.59823506]),
#  array([1367.59823506]),
#  array([1318.59823506]),
#  array([1312.59823506]),
#  array([1281.59823506]),
#  array([1189.59823506]),
#  array([1270.59823506]),
#  array([1222.59823506]),
#  array([1343.59823506]),
#  array([1201.59823506]),
#  array([1174.59823506]),
#  array([1308.59823506]),
#  array([1266.59823506]),
#  array([1269.59823506]),
#  array([1248.59823506]),
#  array([1243.59823506]),
#  array([1153.59823506]),
#  array([1315.59823506]),
#  array([1233.59823506]),
#  array([1258.59823506]),
#  array([1188.59823506]),
#  array([1180.59823506]),
#  array([1123.59823506]),
#  array([1014.59823506]),
#  array([1046.59823506]),
#  array([1123.59823506]),
#  array([1026.59823506]),
#  array([1013.59823506]),
#  array([1071.59823506]),
#  array([1031.59823506]),
#  array([1204.59823506]),
#  array([1161.59823506]),
#  array([1207.59823506]),
#  array([1308.59823506]),
#  array([1184.59823506]),
#  array([1164.59823506]),
#  array([1092.59823506]),
#  array([1086.59823506]),
#  array([1212.59823506]),
#  array([1273.59823506]),
#  array([1302.59823506]),
#  array([1286.59823506]),
#  array([1298.59823506]),
#  array([1208.59823506]),
#  array([1202.59823506]),
#  array([1198.59823506]),
#  array([1259.59823506]),
#  array([1196.59823506]),
#  array([1210.59823506]),
#  array([1139.59823506]),
#  array([1261.59823506]),
#  array([1174.59823506]),
#  array([1139.59823506]),
#  array([1007.59823506]),
#  array([1004.59823506]),
#  array([934.59823506]),
#  array([892.59823506]),
#  array([963.59823506]),
#  array([759.59823506]),
#  array([714.59823506]),
#  array([704.59823506]),
#  array([690.59823506]),
#  array([582.59823506]),
#  array([574.59823506]),
#  array([533.59823506]),
#  array([520.59823506]),
#  array([465.59823506]),
#  array([470.59823506]),
#  array([395.59823506]),
#  array([391.59823506]),
#  array([363.59823506]),
#  array([356.59823506]),
#  array([298.59823506]),
#  array([263.59823506]),
#  array([282.59823506]),
#  array([279.59823506]),
#  array([244.59823506]),
#  array([1269.59823506]),
#  array([1211.59823506]),
#  array([1195.59823506]),
#  array([1130.59823506]),
#  array([1024.59823506]),
#  array([960.59823506]),
#  array([880.59823506]),
#  array([797.59823506]),
#  array([827.59823506]),
#  array([660.59823506]),
#  array([406.59823506]),
#  array([512.59823506]),
#  array([475.59823506]),
#  array([516.59823506]),
#  array([517.59823506]),
#  array([462.59823506]),
#  array([450.59823506]),
#  array([378.59823506]),
#  array([384.59823506]),
#  array([347.59823506]),
#  array([341.59823506]),
#  array([292.59823506]),
#  array([278.59823506]),
#  array([220.59823506]),
#  array([255.59823506]),
#  array([234.59823506]),
#  array([239.59823506]),
#  array([209.59823506]),
#  array([235.59823506]),
#  array([211.59823506]),
#  array([201.59823506]),
#  array([173.59823506]),
#  array([175.59823506]),
#  array([206.59823506]),
#  array([163.59823506]),
#  array([196.59823506]),
#  array([189.59823506]),
#  array([206.59823506]),
#  array([223.59823506]),
#  array([255.59823506]),
#  array([298.59823506]),
#  array([341.59823506]),
#  array([380.59823506]),
#  array([442.59823506]),
#  array([505.59823506]),
#  array([592.59823506]),
#  array([721.59823506]),
#  array([840.59823506]),
#  array([1030.59823506]),
#  array([1143.59823506]),
#  array([1353.59823506]),
#  array([1350.59823506]),
#  array([1396.59823506]),
#  array([1349.59823506]),
#  array([1458.59823506]),
#  array([1482.59823506]),
#  array([1431.59823506]),
#  array([1431.59823506]),
#  array([1512.59823506]),
#  array([1430.59823506]),
#  array([1387.59823506]),
#  array([1404.59823506]),
#  array([1432.59823506]),
#  array([1323.59823506]),
#  array([1356.59823506]),
#  array([1297.59823506]),
#  array([1231.59823506]),
#  array([1297.59823506]),
#  array([1257.59823506]),
#  array([1327.59823506]),
#  array([1267.59823506]),
#  array([1236.59823506]),
#  array([1234.59823506]),
#  array([1236.59823506]),
#  array([1301.59823506]),
#  array([1252.59823506]),
#  array([1210.59823506]),
#  array([1363.59823506]),
#  array([1192.59823506]),
#  array([1194.59823506]),
#  array([1234.59823506]),
#  array([1212.59823506]),
#  array([1299.59823506]),
#  array([1231.59823506]),
#  array([1236.59823506]),
#  array([1292.59823506]),
#  array([1262.59823506]),
#  array([1245.59823506]),
#  array([1344.59823506]),
#  array([1247.59823506]),
#  array([1337.59823506]),
#  array([1279.59823506]),
#  array([1270.59823506]),
#  array([1202.59823506]),
#  array([1344.59823506]),
#  array([1260.59823506]),
#  array([1267.59823506]),
#  array([1218.59823506]),
#  array([1231.59823506]),
#  array([1231.59823506]),
#  array([1216.59823506]),
#  array([1259.59823506]),
#  array([1253.59823506]),
#  array([1269.59823506]),
#  array([1258.59823506]),
#  array([1408.59823506]),
#  array([1266.59823506]),
#  array([1272.59823506]),
#  array([1285.59823506]),
#  array([1281.59823506]),
#  array([1257.59823506]),
#  array([1193.59823506]),
#  array([1139.59823506]),
#  array([1087.59823506]),
#  array([956.59823506]),
#  array([1105.59823506]),
#  array([1131.59823506]),
#  array([1040.59823506]),
#  array([978.59823506]),
#  array([1097.59823506]),
#  array([977.59823506]),
#  array([1114.59823506]),
#  array([997.59823506]),
#  array([965.59823506]),
#  array([1078.59823506]),
#  array([1183.59823506]),
#  array([1228.59823506]),
#  array([1179.59823506]),
#  array([1258.59823506]),
#  array([1181.59823506]),
#  array([1317.59823506]),
#  array([1249.59823506]),
#  array([1145.59823506]),
#  array([1045.59823506]),
#  array([1191.59823506]),
#  array([1115.59823506]),
#  array([1230.59823506]),
#  array([1241.59823506]),
#  array([1170.59823506]),
#  array([1119.59823506]),
#  array([1055.59823506]),
#  array([1035.59823506]),
#  array([1083.59823506]),
#  array([1088.59823506]),
#  array([1080.59823506]),
#  array([1024.59823506]),
#  array([1012.59823506]),
#  array([970.59823506]),
#  array([940.59823506]),
#  array([904.59823506]),
#  array([790.59823506]),
#  array([789.59823506]),
#  array([680.59823506]),
#  array([593.59823506])]

# %%
data = xlrd.open_workbook('Data.xls')
table = data.sheets()[0]
table2 = data.sheets()[1]
raw_flow = table.col_values(0)
raw_flow2 = table2.col_values(0)
flow = np.array([i for i in raw_flow[1:]])
flow2 = np.array([i for i in raw_flow2[1:]])
series = pd.DataFrame(flow)

# %%
raw_values = series.values
diff_values = difference(raw_values,1)

# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values,1)
supervised_values = supervised.values
# Out:
# (8783, 1)
# [             0
# 0          NaN
# 1      [-14.0]
# 2      [-97.0]
# 3        [0.0]
# 4      [-46.0]
# 5      [-56.0]
# 6      [-18.0]
# 7       [-4.0]
# 8       [-5.0]
# 9      [-14.0]
# 10     [-51.0]
# 11     [-16.0]
# 12       [3.0]
# 13     [-49.0]
# 14     [-50.0]
# 15     [-24.0]
# 16     [-12.0]
# 17     [-50.0]
# 18       [5.0]
# 19       [2.0]
# 20     [-13.0]
# 21     [-79.0]
# 22      [69.0]
# 23     [-65.0]
# 24     [-13.0]
# 25      [31.5]
# 26      [38.5]
# 27     [-13.0]
# 28       [9.0]
# 29      [24.0]
# ...        ...
# 8753   [-32.0]
# 8754   [113.0]
# 8755   [105.0]
# 8756    [45.0]
# 8757   [-49.0]
# 8758    [79.0]
# 8759   [-77.0]
# 8760   [136.0]
# 8761   [-68.0]
# 8762  [-104.0]
# 8763  [-100.0]
# 8764   [146.0]
# 8765   [-76.0]
# 8766   [115.0]
# 8767    [11.0]
# 8768   [-71.0]
# 8769   [-51.0]
# 8770   [-64.0]
# 8771   [-20.0]
# 8772    [48.0]
# 8773     [5.0]
# 8774    [-8.0]
# 8775   [-56.0]
# 8776   [-12.0]
# 8777   [-42.0]
# 8778   [-30.0]
# 8779   [-36.0]
# 8780  [-114.0]
# 8781    [-1.0]
# 8782  [-109.0]
#
# [8783 rows x 1 columns]]
# (8783, 2)

# %%
supervised_values
# Out:
# array([[nan, array([-14.])],
#        [array([-14.]), array([-97.])],
#        [array([-97.]), array([0.])],
#        ...,
#        [array([-114.]), array([-1.])],
#        [array([-1.]), array([-109.])],
#        [array([-109.]), array([-87.])]], dtype=object)

# %%
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-d6579f534729> in <module>()
# ----> 1 import tensorflow
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
print("1×1=1\n")
